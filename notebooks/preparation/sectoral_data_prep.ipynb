# %%
import datetime

import numpy as np
import pandas as pd
import scipy.stats
from matplotlib import pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, PowerTransformer, FunctionTransformer, StandardScaler
from sklearn.svm import LinearSVR, SVR
from xgboost import XGBRegressor

from utils.ml_data_provider import SectoralDataProvider

# %%
data_provider = SectoralDataProvider(cache_path='/Users/j4yzer/PycharmProjects/VKR/data/sectoral_ml')
data : pd.DataFrame = data_provider.load_data()

data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d', utc=False)

# data = data.set_index('date')
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20675 entries, 0 to 20674
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ticker                                   20675 non-null  object
#  1   date                                     20675 non-null  datetime64[ns]
#  2   sector                                   20675 non-null  object
#  3   sectoralIndex                            20675 non-null  object
#  4   absoluteReturn                           19209 non-null  float64
#  5   relativeToSPReturn                       19209 non-null  float64
#  6   relativeToSectoralIndexReturn            19209 non-null  float64
#  7   nextPeriodRelativeToSectoralIndexReturn  19209 non-null  float64
#  8   closePrice                               20675 non-null  float64
#  9   dilutedEarningsPerShare                  20675 non-null  float64
#  10  freeCashFlowPerShare                     20675 non-null  float64
#  11  bookValuePerShare                        20675 non-null  float64
#  12  equityRatio                              20675 non-null  float64
#  13  marketCap                                20675 non-null  float64
#  14  priceToEarningsRatio                     20675 non-null  float64
#  15  priceToSalesRatio                        20675 non-null  float64
#  16  priceToFreeCashFlow                      20675 non-null  float64
#  17  priceToBookRatio                         20675 non-null  float64
#  18  enterpriseValueToSalesRatio              20675 non-null  float64
#  19  currentRatio                             20675 non-null  float64
#  20  roic                                     20675 non-null  float64
#  21  netCurrentAssetValuePerShare             20675 non-null  float64
#  22  ebitdaMargin                             20675 non-null  float64
#  23  netIncomeMargin                          20675 non-null  float64
#  24  returnOnAssets                           20675 non-null  float64
#  25  returnOnEquity                           20675 non-null  float64
# dtypes: datetime64[ns](1), float64(22), object(3)
# memory usage: 4.1+ MB
#        absoluteReturn  relativeToSPReturn  relativeToSectoralIndexReturn  \
# count    1.920900e+04        1.920900e+04                   1.920900e+04
# mean              inf                 inf                            inf
# std               NaN                 NaN                            NaN
# min     -1.000000e+00       -9.505327e-01                  -9.726245e-01
# 25%     -6.722966e-02       -8.005409e-02                  -7.233059e-02
# 50%      3.159665e-02        5.274651e-03                   5.118437e-03
# 75%      1.392366e-01        9.811018e-02                   9.195576e-02
# max               inf                 inf                            inf
#
#        nextPeriodRelativeToSectoralIndexReturn    closePrice  \
# count                             1.920900e+04  20675.000000
# mean                                       inf     48.993744
# std                                        NaN     63.675534
# min                              -9.726245e-01      0.000000
# 25%                              -7.233059e-02     15.295000
# 50%                               5.118437e-03     32.280000
# 75%                               9.195576e-02     60.050000
# max                                        inf   1777.230000
#
#        dilutedEarningsPerShare  freeCashFlowPerShare  bookValuePerShare  \
# count             2.067500e+04          20675.000000       20675.000000
# mean                       NaN              0.547413          28.182981
# std                        NaN             42.691063         178.631231
# min                       -inf          -3049.391300       -1021.364200
# 25%               8.712618e-02             -0.035600           7.106450
# 50%               4.273292e-01              0.344200          14.594900
# 75%               1.000837e+00              1.031600          25.952450
# max                        inf           2217.021200        5743.304300
#
#         equityRatio     marketCap  ...  priceToFreeCashFlow  priceToBookRatio  \
# count  20675.000000  2.067500e+04  ...         20675.000000      20675.000000
# mean       0.432702  1.922698e+10  ...            31.681448          2.615234
# std        0.217576  3.917058e+10  ...          1498.330549         64.835246
# min       -2.040700  0.000000e+00  ...        -16096.367900      -8717.450000
# 25%        0.325500  1.906255e+09  ...             0.000000          1.186900
# 50%        0.434200  6.308645e+09  ...            13.113600          2.084600
# 75%        0.552150  1.976868e+10  ...            24.332500          3.552700
# max        1.000000  1.041448e+12  ...        188750.580000        926.276800
#
#        enterpriseValueToSalesRatio  currentRatio          roic  \
# count                 20675.000000  20675.000000  20675.000000
# mean                      7.888780      2.452396      0.084762
# std                     379.846695     10.321225      0.772190
# min                    -338.000000      0.000000    -60.000000
# 25%                       0.879300      1.104600      0.021800
# 50%                       1.753300      1.592900      0.074300
# 75%                       3.177400      2.371900      0.133200
# max                   42707.400000    945.062000     45.846100
#
#        netCurrentAssetValuePerShare  ebitdaMargin  netIncomeMargin  \
# count                  2.067500e+04  20675.000000     20675.000000
# mean                           -inf      0.064115        -0.186277
# std                             NaN     12.290531        17.683512
# min                            -inf  -1395.000000     -2014.000000
# 25%                   -2.117023e+01      0.115000         0.022100
# 50%                   -8.463073e+00      0.194000         0.076200
# 75%                   -1.483547e+00      0.345200         0.143400
# max                    9.749637e+01    219.000000       136.666600
#
#        returnOnAssets  returnOnEquity
# count    20675.000000    20675.000000
# mean         0.051213        0.117414
# std          0.205015        2.513563
# min         -3.254600     -257.973600
# 25%          0.016450        0.037850
# 50%          0.052500        0.125800
# 75%          0.090700        0.217700
# max         17.854400       97.272700
#
# [8 rows x 22 columns]

# %%
data = data.replace([-np.Inf, np.Inf], np.nan)
data = data.dropna()
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18791 entries, 1 to 20383
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ticker                                   18791 non-null  object
#  1   date                                     18791 non-null  datetime64[ns]
#  2   sector                                   18791 non-null  object
#  3   sectoralIndex                            18791 non-null  object
#  4   absoluteReturn                           18791 non-null  float64
#  5   relativeToSPReturn                       18791 non-null  float64
#  6   relativeToSectoralIndexReturn            18791 non-null  float64
#  7   nextPeriodRelativeToSectoralIndexReturn  18791 non-null  float64
#  8   closePrice                               18791 non-null  float64
#  9   dilutedEarningsPerShare                  18791 non-null  float64
#  10  freeCashFlowPerShare                     18791 non-null  float64
#  11  bookValuePerShare                        18791 non-null  float64
#  12  equityRatio                              18791 non-null  float64
#  13  marketCap                                18791 non-null  float64
#  14  priceToEarningsRatio                     18791 non-null  float64
#  15  priceToSalesRatio                        18791 non-null  float64
#  16  priceToFreeCashFlow                      18791 non-null  float64
#  17  priceToBookRatio                         18791 non-null  float64
#  18  enterpriseValueToSalesRatio              18791 non-null  float64
#  19  currentRatio                             18791 non-null  float64
#  20  roic                                     18791 non-null  float64
#  21  netCurrentAssetValuePerShare             18791 non-null  float64
#  22  ebitdaMargin                             18791 non-null  float64
#  23  netIncomeMargin                          18791 non-null  float64
#  24  returnOnAssets                           18791 non-null  float64
#  25  returnOnEquity                           18791 non-null  float64
# dtypes: datetime64[ns](1), float64(22), object(3)
# memory usage: 3.9+ MB
#        absoluteReturn  relativeToSPReturn  relativeToSectoralIndexReturn  \
# count    18791.000000        18791.000000                   18791.000000
# mean         0.043209            0.019861                       0.019986
# std          0.224688            0.199733                       0.183917
# min         -0.943074           -0.868436                      -0.955658
# 25%         -0.067228           -0.081466                      -0.073122
# 50%          0.031616            0.003875                       0.004017
# 75%          0.137967            0.095840                       0.089772
# max          2.849057            2.732176                       2.627580
#
#        nextPeriodRelativeToSectoralIndexReturn    closePrice  \
# count                             18791.000000  18791.000000
# mean                                  0.019528     52.236485
# std                                   0.182372     63.062626
# min                                  -0.972624      0.010000
# 25%                                  -0.072742     18.515000
# 50%                                   0.003972     35.050000
# 75%                                   0.089375     63.385000
# max                                   2.627580   1599.740000
#
#        dilutedEarningsPerShare  freeCashFlowPerShare  bookValuePerShare  \
# count             18791.000000          18791.000000       18791.000000
# mean                  0.643500              0.557155          21.262092
# std                   3.378358              1.895245          36.291237
# min                -155.800325            -43.374600         -74.895400
# 25%                   0.111079             -0.027600           7.767500
# 50%                   0.453408              0.373800          15.228900
# 75%                   1.023903              1.053000          26.360950
# max                 283.036184             31.563000        2327.725300
#
#         equityRatio     marketCap  ...  priceToFreeCashFlow  priceToBookRatio  \
# count  18791.000000  1.879100e+04  ...         18791.000000      18791.000000
# mean       0.442125  2.056956e+10  ...            34.225321          2.752549
# std        0.199597  3.962972e+10  ...          1570.554497         67.737100
# min       -2.025900  4.046290e+06  ...        -16096.367900      -8717.450000
# 25%        0.333900  2.466253e+09  ...             5.000850          1.347200
# 50%        0.438100  7.351087e+09  ...            14.421400          2.216800
# 75%        0.552750  2.155874e+10  ...            25.496350          3.700650
# max        1.000000  5.057136e+11  ...        188750.580000        926.276800
#
#        enterpriseValueToSalesRatio  currentRatio          roic  \
# count                 18791.000000  18791.000000  18791.000000
# mean                      7.114360      2.369996      0.086677
# std                     348.464641      4.995833      0.544030
# min                    -323.187100      0.000000     -9.714900
# 25%                       0.987700      1.134800      0.026500
# 50%                       1.880900      1.627300      0.076900
# 75%                       3.311700      2.411750      0.134600
# max                   42707.400000    301.083300     45.846100
#
#        netCurrentAssetValuePerShare  ebitdaMargin  netIncomeMargin  \
# count                  18791.000000  18791.000000     18791.000000
# mean                     -15.923386      0.145815        -0.103950
# std                       25.657805      7.562779        15.755655
# min                     -294.656175   -732.000000     -2014.000000
# 25%                      -21.331817      0.118400         0.027000
# 50%                       -8.740189      0.194900         0.077800
# 75%                       -1.625384      0.340400         0.142700
# max                       77.369916    219.000000       136.666600
#
#        returnOnAssets  returnOnEquity
# count    18791.000000    18791.000000
# mean         0.053325        0.123919
# std          0.140794        2.541372
# min         -3.254600     -257.973600
# 25%          0.020200        0.044300
# 50%          0.054400        0.129700
# 75%          0.091700        0.218800
# max          8.892700       97.272700
#
# [8 rows x 22 columns]

# %%
data_by_sector = data.groupby('sector')
print(data_by_sector.groups.keys())
# for sector, sector_data in data_by_sector:
#     print(sector)
#     sector_data.info()
# Out:
# dict_keys(['Energy', 'Industrials', 'Materials'])

# %%
def drop_outliers_iqr(df, iqr_bound=(0.25, 0.75), IQR_k=7):
    Q1 = df.quantile(iqr_bound[0])
    Q3 = df.quantile(iqr_bound[1])
    IQR = Q3 - Q1
    return df[~((df < (Q1 - IQR_k * IQR)) | (df > (Q3 + IQR_k * IQR))).any(axis=1)]
def drop_outliers_quantile(df, keep_inside_quantiles_bounds = (0.01, 0.99)):
    q_l = df.quantile(keep_inside_quantiles_bounds[0])
    q_u = df.quantile(keep_inside_quantiles_bounds[1])
    print(keep_inside_quantiles_bounds)
    return df[~((df < q_l) | (df > q_u)).any(axis=1)]

def visualise_data(df: pd.DataFrame, remove_outliers=True, remove_outliers_function=drop_outliers_quantile, remove_outliers_kwargs = None):
    df_to_visualize = df.copy()
    if remove_outliers:
        df_to_visualize = remove_outliers_function(df_to_visualize, **remove_outliers_kwargs)
        print(df.index.size - df_to_visualize.index.size)
    df_to_visualize.hist(bins=50, figsize=(20, 15))
    fig, axes = plt.subplots(5, int(np.ceil(len(df_to_visualize.columns) / 5)), figsize=(20, 15))
    for i,el in enumerate(list(df_to_visualize.columns.values)):
        df_to_visualize.boxplot([el], ax=axes.flatten()[i])
    plt.tight_layout()
    plt.show()
def eval(model, features, labels):
    predictions = model.predict(features)
    errors = abs(predictions - labels)
    mape = 100 * np.mean(errors / labels)
    accuracy = 100 - mape
    print('Model Performance')
    stats = pd.DataFrame([('RMSE', mean_squared_error(labels, predictions, squared=False)),(
                  'MAE', mean_absolute_error(labels, predictions)),(
                  'R2', r2_score(labels, predictions))], columns=['Статистика', 'Значение'])
    print(stats)
    return stats

# %%
split_data_by_sector = {sector: train_test_split(sector_data.drop(['ticker', 'sector', 'sectoralIndex', 'date'], axis=1), test_size=0.2, shuffle=False) for sector, sector_data in data_by_sector}
train_data_by_sector = {k: v[0] for k, v in split_data_by_sector.items()}
test_data_by_sector = {k: v[1] for k, v in split_data_by_sector.items()}

# for sector, train_data in train_data_by_sector.items():
#     print(sector)
#     visualise_data(train_data, remove_outliers=False)

# %%
# for sector, train_data in train_data_by_sector.items():
#     print(sector)
#     visualise_data(train_data, remove_outliers=True, remove_outliers_function=drop_outliers_iqr, remove_outliers_kwargs={'IQR_k': 30})
len(data_by_sector.get_group('Materials')
    [(data_by_sector.get_group('Materials')['date'] >= '2003-1-19') & (data_by_sector.get_group('Materials')['date'] <= '2009-1-19')])
# Out:
# 1738

# %%
log_transform = FunctionTransformer(np.log)
r_scaler = RobustScaler()
p_scaler = PowerTransformer()

long_tail_scaler = make_pipeline(p_scaler)
normal_scaler = make_pipeline(r_scaler)


train_data_by_sector = {k: drop_outliers_iqr(v, IQR_k=30) for k, v in train_data_by_sector.items()}
y_train_by_sector = {k: v['nextPeriodRelativeToSectoralIndexReturn'] for k, v in train_data_by_sector.items()}
X_train_by_sector = {k: v.drop(['nextPeriodRelativeToSectoralIndexReturn'], axis=1) for k, v in train_data_by_sector.items()}

long_tail_columns = ['closePrice', 'bookValuePerShare', 'marketCap', 'priceToSalesRatio', 'enterpriseValueToSalesRatio', 'currentRatio', 'netCurrentAssetValuePerShare']
noraml_columns = [k for k in X_train_by_sector[list(X_train_by_sector.keys())[0]].columns if k not in long_tail_columns]
prep_pipeline = ColumnTransformer([('lt', long_tail_scaler, long_tail_columns), ('normal', normal_scaler, noraml_columns)])

# X_train_by_sector_scaled = {k: pd.DataFrame(prep_pipeline.fit_transform(X=v), columns=v.columns, index=v.index) for k, v in X_train_by_sector.items()}
# for sector, X_train_scaled in X_train_by_sector_scaled.items():
#     print(sector)
#     visualise_data(X_train_scaled, remove_outliers=False)

# %%
from sklearn.model_selection import TimeSeriesSplit
def get_cross_val_row(cross_val_res, stat, algo, stat_metrics=['mean', 'std']):
    stat_map = {'r2': 'R2', 'neg_mean_absolute_error': 'MAE', 'neg_root_mean_squared_error': 'RMSE'}
    stat = stat_map[stat]
    stats = pd.Series(cross_val_res).describe().to_frame('Значение').reset_index().rename({'index': 'Показатель статистики'}, axis=1)
    stats.insert(0, 'Статистика', value=stat)
    stats.insert(0, 'Алгоритм', value=algo)
    return stats[stats['Показатель статистики'].isin(stat_metrics)]
scorings = ['r2', 'neg_mean_absolute_error', 'neg_root_mean_squared_error']

test_data_by_sector = {k: drop_outliers_iqr(v, IQR_k=30) for k, v in test_data_by_sector.items()}
y_test_by_sector = {k: v['nextPeriodRelativeToSectoralIndexReturn'] for k, v in test_data_by_sector.items()}
X_test_by_sector = {k: v.drop(['nextPeriodRelativeToSectoralIndexReturn'], axis=1) for k, v in test_data_by_sector.items()}


linear_regr_pipeline = make_pipeline(prep_pipeline, LinearRegression())

svr_pipeline = make_pipeline(prep_pipeline, SVR(C=1.2, gamma=1e-5))

random_forest_pipeline = make_pipeline(prep_pipeline, RandomForestRegressor(max_features=8, max_depth=5, n_estimators=300, bootstrap=True,random_state=42))

pipelines = [('Linear regr', linear_regr_pipeline), ('SVR', svr_pipeline)
    , ('Random forest', random_forest_pipeline)]


out_table = None
for sector, y_train_data in y_train_by_sector.items():
    print(sector)
    sector_data_size = len(data_by_sector.get_group(sector))
    X_train_data = X_train_by_sector[sector]
    X_test_data = X_test_by_sector[sector]
    y_test_data = y_test_by_sector[sector]
    methods_table_for_sector = pd.DataFrame(columns=['Алгоритм', 'Статистика','Показатель статистики', 'Значение'])
    for name, pipeline in pipelines:
        print(name)
        cv_num = 10
        for scoring in scorings:
            # TimeSeriesSplit(n_splits=5, test_size=int(sector_data_size * 0.035), max_train_size=int(sector_data_size * 0.15))
            scrs = -cross_val_score(pipeline, X_train_data, y_train_data,
                                      scoring=scoring, cv=TimeSeriesSplit(n_splits=5, test_size=int(sector_data_size * 0.035)))
            print(pd.Series(scrs).describe())
            methods_table_for_sector = pd.concat([methods_table_for_sector, get_cross_val_row(scrs, scoring, name)])

        est = pipeline.fit(X_train_data, y_train_data)

        print('train: ')
        eval(est, X_train_data, y_train_data)
        print('test: ')
        X_tst_h  = X_test_data.head(int(sector_data_size * 0.035))
        y_tst_h = y_test_data.head(int(sector_data_size * 0.035))
        eval(est, X_tst_h, y_tst_h)

    out = pd.Series(methods_table_for_sector['Значение'].array, index=pd.MultiIndex.from_frame(methods_table_for_sector.drop('Значение', axis=1))).to_frame(sector).transpose()
    if out_table is None:
        out_table = out
    else:
        out_table = pd.concat([out_table, out])
print(out_table)
out_table.to_excel('out_table_init_ts.xlsx')
# Out:
# pydev debugger: Unable to find real location for: C:\Users\j4yze\AppData\Local\Temp\ipykernel_7520\1743288561.py
# pydev debugger: Unable to find real location for: C:\Users\j4yze\AppData\Local\Temp\ipykernel_7520\3668116294.py
# pydev debugger: Unable to find real location for: C:\Users\j4yze\AppData\Local\Temp\ipykernel_7520\453956364.py
# Energy
# Linear regr
# count    5.000000
# mean     0.079419
# std      0.053968
# min      0.015884
# 25%      0.032126
# 50%      0.087126
# 75%      0.130674
# max      0.131286
# dtype: float64
# count    5.000000
# mean     0.100113
# std      0.008394
# min      0.089320
# 25%      0.096158
# 50%      0.097860
# 75%      0.108339
# max      0.108885
# dtype: float64
# count    5.000000
# mean     0.133694
# std      0.009826
# min      0.124751
# 25%      0.126508
# 50%      0.131232
# 75%      0.136837
# max      0.149142
# dtype: float64
# train:
# Model Performance
#   Статистика             Значение
# 0        MSE  0.14437982789863424
# 1        MAE  0.10308785862649283
# 2         R2  0.03649232026656679
# test:
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:605: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s = s[:max_items]
# D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_utils.py:606: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in s.iteritems():
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 51
#      49     X_tst_h  = X_test_data.head(int(sector_data_size * 0.035))
#      50     y_tst_h = y_test_data.head(int(sector_data_size * 0.035))
# ---> 51     eval(est, X_tst_h, y_tst_h)
#      53 out = pd.Series(methods_table_for_sector['Значение'].array, index=pd.MultiIndex.from_frame(methods_table_for_sector.drop('Значение', axis=1))).to_frame(sector).transpose()
#      54 if out_table is None:
#
# Cell In[60], line 51
#      49     X_tst_h  = X_test_data.head(int(sector_data_size * 0.035))
#      50     y_tst_h = y_test_data.head(int(sector_data_size * 0.035))
# ---> 51     eval(est, X_tst_h, y_tst_h)
#      53 out = pd.Series(methods_table_for_sector['Значение'].array, index=pd.MultiIndex.from_frame(methods_table_for_sector.drop('Значение', axis=1))).to_frame(sector).transpose()
#      54 if out_table is None:
#
# File D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_frame.py:747, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     745 # if thread has a suspend flag, we suspend with a busy wait
#     746 if info.pydev_state == STATE_SUSPEND:
# --> 747     self.do_wait_suspend(thread, frame, event, arg)
#     748     # No need to reset frame.f_trace to keep the same trace function.
#     749     return self.trace_dispatch
#
# File D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_frame.py:144, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     143 def do_wait_suspend(self, *args, **kwargs):
# --> 144     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\pydevd.py:1160, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1157         from_this_thread.append(frame_id)
#    1159 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1160     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File D:\Programs\JBApps\apps\PyCharm-P\ch-0\222.4345.23\plugins\python\helpers\pydev\pydevd.py:1175, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1172             self._call_mpl_hook()
#    1174         self.process_internal_commands()
# -> 1175         time.sleep(0.01)
#    1177 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1179 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
svr_pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('lt',
#                                                   Pipeline(steps=[('powertransformer',
#                                                                    PowerTransformer())]),
#                                                   ['closePrice',
#                                                    'bookValuePerShare',
#                                                    'marketCap',
#                                                    'priceToSalesRatio',
#                                                    'enterpriseValueToSalesRatio',
#                                                    'currentRatio',
#                                                    'netCurrentAssetValuePerShare']),
#                                                  ('normal',
#                                                   Pipeline(steps=[('robustscaler',
#                                                                    RobustScaler())]),
#                                                   ['absoluteReturn',
#                                                    'relativeToSPReturn',
#                                                    'relativeToSectoralIndexReturn',
#                                                    'dilutedEarningsPerShare',
#                                                    'freeCashFlowPerShare',
#                                                    'equityRatio',
#                                                    'priceToEarningsRatio',
#                                                    'priceToFreeCashFlow',
#                                                    'priceToBookRatio', 'roic',
#                                                    'ebitdaMargin',
#                                                    'netIncomeMargin',
#                                                    'returnOnAssets',
#                                                    'returnOnEquity'])])),
#                 ('svr', SVR())])

# %%
svm_param_grid = [{'svr__C': [0.1, 1, 1.2, 1.5, 5],
              'svr__gamma': [0.01, 0.001, 0.0001],
              'svr__kernel': ['rbf']},]

y_train_data = y_train_by_sector['Materials']
X_train_data = X_train_by_sector['Materials']
grid = GridSearchCV(svr_pipeline, svm_param_grid, scoring='r2', refit = True, verbose = 3, cv=3)
res = grid.fit(X_train_data, y_train_data)
print(res.best_params_)
print(res.best_score_)
# Out:
# Fitting 4 folds for each of 15 candidates, totalling 60 fits
# [CV 1/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.201 total time=   2.0s
# [CV 2/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.225 total time=   1.2s
# [CV 3/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.203 total time=   1.1s
# [CV 4/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.174 total time=   1.0s
# [CV 1/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.202 total time=   0.8s
# [CV 2/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.223 total time=   0.7s
# [CV 3/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.201 total time=   0.8s
# [CV 4/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.174 total time=   0.8s
# [CV 1/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.201 total time=   0.8s
# [CV 2/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.222 total time=   0.9s
# [CV 3/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.199 total time=   0.8s
# [CV 4/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.173 total time=   1.1s
# [CV 1/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.200 total time=   0.8s
# [CV 2/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.223 total time=   0.7s
# [CV 3/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.201 total time=   0.8s
# [CV 4/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.173 total time=   0.8s
# [CV 1/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.201 total time=   1.0s
# [CV 2/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.224 total time=   1.0s
# [CV 3/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.201 total time=   1.2s
# [CV 4/4] END svr__C=0.1, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.173 total time=   1.5s
# [CV 1/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.199 total time=   1.7s
# [CV 2/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.224 total time=   1.6s
# [CV 3/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.208 total time=   1.7s
# [CV 4/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.177 total time=   1.9s
# [CV 1/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.211 total time=   1.6s
# [CV 2/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.227 total time=   1.6s
# [CV 3/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.209 total time=   1.7s
# [CV 4/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.182 total time=   1.7s
# [CV 1/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.206 total time=   1.5s
# [CV 2/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.220 total time=   1.6s
# [CV 3/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.203 total time=   1.8s
# [CV 4/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.178 total time=   1.1s
# [CV 1/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.201 total time=   1.0s
# [CV 2/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.223 total time=   1.0s
# [CV 3/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.201 total time=   1.3s
# [CV 4/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.174 total time=   1.0s
# [CV 1/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.201 total time=   1.8s
# [CV 2/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.223 total time=   1.3s
# [CV 3/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.200 total time=   1.0s
# [CV 4/4] END svr__C=1, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.173 total time=   0.9s
# [CV 1/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.198 total time=   2.1s
# [CV 2/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.224 total time=   2.2s
# [CV 3/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.209 total time=   4.0s
# [CV 4/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=1, svr__kernel=rbf;, score=-0.178 total time=   2.9s
# [CV 1/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.232 total time=   4.5s
# [CV 2/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.247 total time=   2.4s
# [CV 3/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.223 total time=   2.4s
# [CV 4/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=-0.204 total time=   2.4s
# [CV 1/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.222 total time=   3.0s
# [CV 2/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.234 total time=   3.0s
# [CV 3/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.210 total time=   2.6s
# [CV 4/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=-0.191 total time=   2.8s
# [CV 1/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.203 total time=   1.5s
# [CV 2/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.223 total time=   2.3s
# [CV 3/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.203 total time=   1.5s
# [CV 4/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=-0.177 total time=   1.5s
# [CV 1/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.201 total time=   1.2s
# [CV 2/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.224 total time=   1.2s
# [CV 3/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.201 total time=   1.2s
# [CV 4/4] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.0001, svr__kernel=rbf;, score=-0.174 total time=   1.2s
# {'svr__C': 0.1, 'svr__epsilon': 0.1, 'svr__gamma': 0.01, 'svr__kernel': 'rbf'}
# -0.19880943956866898

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform

from scipy.stats import expon

param_distribs_svr = {
        'svr__kernel': ['rbf'],
        'svr__C': uniform(0.01, 5),
        'svr__gamma': reciprocal(0.0001, 1)
    }
sector_data_size = len(data_by_sector.get_group('Energy'))

rnd_search_svr = RandomizedSearchCV(svr_pipeline,
                                param_distributions=param_distribs_svr,
                                n_iter=23, cv=TimeSeriesSplit(n_splits=7, test_size=int(sector_data_size * 0.035), max_train_size=int(sector_data_size * 0.15)),
                                scoring='neg_mean_absolute_error',
                                verbose=3,
                                random_state=42)
# for sector, y_train_data in y_train_by_sector.items():
#     print(sector)

y_train_data = y_train_by_sector['Energy']
X_train_data = X_train_by_sector['Energy']
res = rnd_search_svr.fit(X_train_data, y_train_data)
print(res.best_params_)
print(res.best_score_)
# C=1.2 gamma = 1e-05
# Out:
# Fitting 5 folds for each of 23 candidates, totalling 115 fits
# [CV 1/5] END svr__C=1.8827005942368125, svr__gamma=0.6351221010640693, svr__kernel=rbf;, score=-0.083 total time=   0.0s
# [CV 2/5] END svr__C=1.8827005942368125, svr__gamma=0.6351221010640693, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=1.8827005942368125, svr__gamma=0.6351221010640693, svr__kernel=rbf;, score=-0.093 total time=   0.0s
# [CV 4/5] END svr__C=1.8827005942368125, svr__gamma=0.6351221010640693, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 5/5] END svr__C=1.8827005942368125, svr__gamma=0.6351221010640693, svr__kernel=rbf;, score=-0.105 total time=   0.0s
# [CV 1/5] END svr__C=3.669969709057025, svr__gamma=0.024810409748678097, svr__kernel=rbf;, score=-0.100 total time=   0.0s
# [CV 2/5] END svr__C=3.669969709057025, svr__gamma=0.024810409748678097, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 3/5] END svr__C=3.669969709057025, svr__gamma=0.024810409748678097, svr__kernel=rbf;, score=-0.122 total time=   0.0s
# [CV 4/5] END svr__C=3.669969709057025, svr__gamma=0.024810409748678097, svr__kernel=rbf;, score=-0.122 total time=   0.0s
# [CV 5/5] END svr__C=3.669969709057025, svr__gamma=0.024810409748678097, svr__kernel=rbf;, score=-0.113 total time=   0.0s
# [CV 1/5] END svr__C=0.7900932022121826, svr__gamma=0.0004207053950287936, svr__kernel=rbf;, score=-0.088 total time=   0.0s
# [CV 2/5] END svr__C=0.7900932022121826, svr__gamma=0.0004207053950287936, svr__kernel=rbf;, score=-0.091 total time=   0.0s
# [CV 3/5] END svr__C=0.7900932022121826, svr__gamma=0.0004207053950287936, svr__kernel=rbf;, score=-0.095 total time=   0.0s
# [CV 4/5] END svr__C=0.7900932022121826, svr__gamma=0.0004207053950287936, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 5/5] END svr__C=0.7900932022121826, svr__gamma=0.0004207053950287936, svr__kernel=rbf;, score=-0.107 total time=   0.0s
# [CV 1/5] END svr__C=0.3004180608409973, svr__gamma=0.29154431891537524, svr__kernel=rbf;, score=-0.085 total time=   0.0s
# [CV 2/5] END svr__C=0.3004180608409973, svr__gamma=0.29154431891537524, svr__kernel=rbf;, score=-0.095 total time=   0.0s
# [CV 3/5] END svr__C=0.3004180608409973, svr__gamma=0.29154431891537524, svr__kernel=rbf;, score=-0.098 total time=   0.0s
# [CV 4/5] END svr__C=0.3004180608409973, svr__gamma=0.29154431891537524, svr__kernel=rbf;, score=-0.113 total time=   0.0s
# [CV 5/5] END svr__C=0.3004180608409973, svr__gamma=0.29154431891537524, svr__kernel=rbf;, score=-0.104 total time=   0.0s
# [CV 1/5] END svr__C=3.0155750587160437, svr__gamma=0.06796578090758153, svr__kernel=rbf;, score=-0.100 total time=   0.0s
# [CV 2/5] END svr__C=3.0155750587160437, svr__gamma=0.06796578090758153, svr__kernel=rbf;, score=-0.109 total time=   0.0s
# [CV 3/5] END svr__C=3.0155750587160437, svr__gamma=0.06796578090758153, svr__kernel=rbf;, score=-0.123 total time=   0.0s
# [CV 4/5] END svr__C=3.0155750587160437, svr__gamma=0.06796578090758153, svr__kernel=rbf;, score=-0.133 total time=   0.0s
# [CV 5/5] END svr__C=3.0155750587160437, svr__gamma=0.06796578090758153, svr__kernel=rbf;, score=-0.118 total time=   0.0s
# [CV 1/5] END svr__C=0.11292247147901223, svr__gamma=0.7579479953347995, svr__kernel=rbf;, score=-0.083 total time=   0.0s
# [CV 2/5] END svr__C=0.11292247147901223, svr__gamma=0.7579479953347995, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=0.11292247147901223, svr__gamma=0.7579479953347995, svr__kernel=rbf;, score=-0.093 total time=   0.0s
# [CV 4/5] END svr__C=0.11292247147901223, svr__gamma=0.7579479953347995, svr__kernel=rbf;, score=-0.109 total time=   0.0s
# [CV 5/5] END svr__C=0.11292247147901223, svr__gamma=0.7579479953347995, svr__kernel=rbf;, score=-0.103 total time=   0.0s
# [CV 1/5] END svr__C=4.172213204002109, svr__gamma=0.0007068974950624602, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 2/5] END svr__C=4.172213204002109, svr__gamma=0.0007068974950624602, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=4.172213204002109, svr__gamma=0.0007068974950624602, svr__kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 4/5] END svr__C=4.172213204002109, svr__gamma=0.0007068974950624602, svr__kernel=rbf;, score=-0.112 total time=   0.0s
# [CV 5/5] END svr__C=4.172213204002109, svr__gamma=0.0007068974950624602, svr__kernel=rbf;, score=-0.107 total time=   0.0s
# [CV 1/5] END svr__C=0.9191248360355031, svr__gamma=0.0005415244119402537, svr__kernel=rbf;, score=-0.089 total time=   0.0s
# [CV 2/5] END svr__C=0.9191248360355031, svr__gamma=0.0005415244119402537, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=0.9191248360355031, svr__gamma=0.0005415244119402537, svr__kernel=rbf;, score=-0.096 total time=   0.0s
# [CV 4/5] END svr__C=0.9191248360355031, svr__gamma=0.0005415244119402537, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 5/5] END svr__C=0.9191248360355031, svr__gamma=0.0005415244119402537, svr__kernel=rbf;, score=-0.107 total time=   0.0s
# [CV 1/5] END svr__C=1.5312112147976886, svr__gamma=0.012561043700013555, svr__kernel=rbf;, score=-0.091 total time=   0.0s
# [CV 2/5] END svr__C=1.5312112147976886, svr__gamma=0.012561043700013555, svr__kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 3/5] END svr__C=1.5312112147976886, svr__gamma=0.012561043700013555, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 4/5] END svr__C=1.5312112147976886, svr__gamma=0.012561043700013555, svr__kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 5/5] END svr__C=1.5312112147976886, svr__gamma=0.012561043700013555, svr__kernel=rbf;, score=-0.107 total time=   0.0s
# [CV 1/5] END svr__C=2.1697250932105785, svr__gamma=0.0014618962793704956, svr__kernel=rbf;, score=-0.093 total time=   0.0s
# [CV 2/5] END svr__C=2.1697250932105785, svr__gamma=0.0014618962793704956, svr__kernel=rbf;, score=-0.091 total time=   0.0s
# [CV 3/5] END svr__C=2.1697250932105785, svr__gamma=0.0014618962793704956, svr__kernel=rbf;, score=-0.098 total time=   0.0s
# [CV 4/5] END svr__C=2.1697250932105785, svr__gamma=0.0014618962793704956, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 5/5] END svr__C=2.1697250932105785, svr__gamma=0.0014618962793704956, svr__kernel=rbf;, score=-0.106 total time=   0.0s
# [CV 1/5] END svr__C=3.0692644736118972, svr__gamma=0.00036138942712165265, svr__kernel=rbf;, score=-0.091 total time=   0.0s
# [CV 2/5] END svr__C=3.0692644736118972, svr__gamma=0.00036138942712165265, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=3.0692644736118972, svr__gamma=0.00036138942712165265, svr__kernel=rbf;, score=-0.095 total time=   0.0s
# [CV 4/5] END svr__C=3.0692644736118972, svr__gamma=0.00036138942712165265, svr__kernel=rbf;, score=-0.111 total time=   0.0s
# [CV 5/5] END svr__C=3.0692644736118972, svr__gamma=0.00036138942712165265, svr__kernel=rbf;, score=-0.107 total time=   0.0s
# [CV 1/5] END svr__C=1.4707232426760908, svr__gamma=0.00292043384718141, svr__kernel=rbf;, score=-0.094 total time=   0.0s
# [CV 2/5] END svr__C=1.4707232426760908, svr__gamma=0.00292043384718141, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=1.4707232426760908, svr__gamma=0.00292043384718141, svr__kernel=rbf;, score=-0.098 total time=   0.0s
# [CV 4/5] END svr__C=1.4707232426760908, svr__gamma=0.00292043384718141, svr__kernel=rbf;, score=-0.109 total time=   0.0s
# [CV 5/5] END svr__C=1.4707232426760908, svr__gamma=0.00292043384718141, svr__kernel=rbf;, score=-0.105 total time=   0.0s
# [CV 1/5] END svr__C=2.2903499210851797, svr__gamma=0.13826232179369854, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 2/5] END svr__C=2.2903499210851797, svr__gamma=0.13826232179369854, svr__kernel=rbf;, score=-0.100 total time=   0.0s
# [CV 3/5] END svr__C=2.2903499210851797, svr__gamma=0.13826232179369854, svr__kernel=rbf;, score=-0.111 total time=   0.0s
# [CV 4/5] END svr__C=2.2903499210851797, svr__gamma=0.13826232179369854, svr__kernel=rbf;, score=-0.126 total time=   0.0s
# [CV 5/5] END svr__C=2.2903499210851797, svr__gamma=0.13826232179369854, svr__kernel=rbf;, score=-0.112 total time=   0.0s
# [CV 1/5] END svr__C=1.0083689107917986, svr__gamma=0.011400863701127315, svr__kernel=rbf;, score=-0.090 total time=   0.0s
# [CV 2/5] END svr__C=1.0083689107917986, svr__gamma=0.011400863701127315, svr__kernel=rbf;, score=-0.095 total time=   0.0s
# [CV 3/5] END svr__C=1.0083689107917986, svr__gamma=0.011400863701127315, svr__kernel=rbf;, score=-0.105 total time=   0.0s
# [CV 4/5] END svr__C=1.0083689107917986, svr__gamma=0.011400863701127315, svr__kernel=rbf;, score=-0.111 total time=   0.0s
# [CV 5/5] END svr__C=1.0083689107917986, svr__gamma=0.011400863701127315, svr__kernel=rbf;, score=-0.105 total time=   0.0s
# [CV 1/5] END svr__C=2.9720728443102122, svr__gamma=0.0001533916259116362, svr__kernel=rbf;, score=-0.090 total time=   0.0s
# [CV 2/5] END svr__C=2.9720728443102122, svr__gamma=0.0001533916259116362, svr__kernel=rbf;, score=-0.090 total time=   0.0s
# [CV 3/5] END svr__C=2.9720728443102122, svr__gamma=0.0001533916259116362, svr__kernel=rbf;, score=-0.095 total time=   0.0s
# [CV 4/5] END svr__C=2.9720728443102122, svr__gamma=0.0001533916259116362, svr__kernel=rbf;, score=-0.109 total time=   0.0s
# [CV 5/5] END svr__C=2.9720728443102122, svr__gamma=0.0001533916259116362, svr__kernel=rbf;, score=-0.108 total time=   0.0s
# [CV 1/5] END svr__C=3.0477242595071914, svr__gamma=0.0004809461967501573, svr__kernel=rbf;, score=-0.091 total time=   0.0s
# [CV 2/5] END svr__C=3.0477242595071914, svr__gamma=0.0004809461967501573, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=3.0477242595071914, svr__gamma=0.0004809461967501573, svr__kernel=rbf;, score=-0.095 total time=   0.0s
# [CV 4/5] END svr__C=3.0477242595071914, svr__gamma=0.0004809461967501573, svr__kernel=rbf;, score=-0.111 total time=   0.0s
# [CV 5/5] END svr__C=3.0477242595071914, svr__gamma=0.0004809461967501573, svr__kernel=rbf;, score=-0.107 total time=   0.0s
# [CV 1/5] END svr__C=0.3352579649263976, svr__gamma=0.6245139574743064, svr__kernel=rbf;, score=-0.083 total time=   0.0s
# [CV 2/5] END svr__C=0.3352579649263976, svr__gamma=0.6245139574743064, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=0.3352579649263976, svr__gamma=0.6245139574743064, svr__kernel=rbf;, score=-0.093 total time=   0.0s
# [CV 4/5] END svr__C=0.3352579649263976, svr__gamma=0.6245139574743064, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 5/5] END svr__C=0.3352579649263976, svr__gamma=0.6245139574743064, svr__kernel=rbf;, score=-0.105 total time=   0.0s
# [CV 1/5] END svr__C=4.838160165372797, svr__gamma=0.17123375973163968, svr__kernel=rbf;, score=-0.090 total time=   0.0s
# [CV 2/5] END svr__C=4.838160165372797, svr__gamma=0.17123375973163968, svr__kernel=rbf;, score=-0.098 total time=   0.0s
# [CV 3/5] END svr__C=4.838160165372797, svr__gamma=0.17123375973163968, svr__kernel=rbf;, score=-0.108 total time=   0.0s
# [CV 4/5] END svr__C=4.838160165372797, svr__gamma=0.17123375973163968, svr__kernel=rbf;, score=-0.123 total time=   0.0s
# [CV 5/5] END svr__C=4.838160165372797, svr__gamma=0.17123375973163968, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 1/5] END svr__C=1.5330688458668533, svr__gamma=0.0002458603276328005, svr__kernel=rbf;, score=-0.089 total time=   0.0s
# [CV 2/5] END svr__C=1.5330688458668533, svr__gamma=0.0002458603276328005, svr__kernel=rbf;, score=-0.090 total time=   0.0s
# [CV 3/5] END svr__C=1.5330688458668533, svr__gamma=0.0002458603276328005, svr__kernel=rbf;, score=-0.095 total time=   0.0s
# [CV 4/5] END svr__C=1.5330688458668533, svr__gamma=0.0002458603276328005, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 5/5] END svr__C=1.5330688458668533, svr__gamma=0.0002458603276328005, svr__kernel=rbf;, score=-0.107 total time=   0.0s
# [CV 1/5] END svr__C=3.431165132560784, svr__gamma=0.005762487216478598, svr__kernel=rbf;, score=-0.098 total time=   0.0s
# [CV 2/5] END svr__C=3.431165132560784, svr__gamma=0.005762487216478598, svr__kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 3/5] END svr__C=3.431165132560784, svr__gamma=0.005762487216478598, svr__kernel=rbf;, score=-0.105 total time=   0.0s
# [CV 4/5] END svr__C=3.431165132560784, svr__gamma=0.005762487216478598, svr__kernel=rbf;, score=-0.113 total time=   0.0s
# [CV 5/5] END svr__C=3.431165132560784, svr__gamma=0.005762487216478598, svr__kernel=rbf;, score=-0.106 total time=   0.0s
# [CV 1/5] END svr__C=0.6201911742238941, svr__gamma=0.009565499215943818, svr__kernel=rbf;, score=-0.089 total time=   0.0s
# [CV 2/5] END svr__C=0.6201911742238941, svr__gamma=0.009565499215943818, svr__kernel=rbf;, score=-0.092 total time=   0.0s
# [CV 3/5] END svr__C=0.6201911742238941, svr__gamma=0.009565499215943818, svr__kernel=rbf;, score=-0.100 total time=   0.0s
# [CV 4/5] END svr__C=0.6201911742238941, svr__gamma=0.009565499215943818, svr__kernel=rbf;, score=-0.109 total time=   0.0s
# [CV 5/5] END svr__C=0.6201911742238941, svr__gamma=0.009565499215943818, svr__kernel=rbf;, score=-0.106 total time=   0.0s
# [CV 1/5] END svr__C=0.181942605576092, svr__gamma=0.43379206974909357, svr__kernel=rbf;, score=-0.084 total time=   0.0s
# [CV 2/5] END svr__C=0.181942605576092, svr__gamma=0.43379206974909357, svr__kernel=rbf;, score=-0.093 total time=   0.0s
# [CV 3/5] END svr__C=0.181942605576092, svr__gamma=0.43379206974909357, svr__kernel=rbf;, score=-0.094 total time=   0.0s
# [CV 4/5] END svr__C=0.181942605576092, svr__gamma=0.43379206974909357, svr__kernel=rbf;, score=-0.110 total time=   0.0s
# [CV 5/5] END svr__C=0.181942605576092, svr__gamma=0.43379206974909357, svr__kernel=rbf;, score=-0.104 total time=   0.0s
# [CV 1/5] END svr__C=1.3038999080000846, svr__gamma=0.04467752817973904, svr__kernel=rbf;, score=-0.094 total time=   0.0s
# [CV 2/5] END svr__C=1.3038999080000846, svr__gamma=0.04467752817973904, svr__kernel=rbf;, score=-0.107 total time=   0.0s
# [CV 3/5] END svr__C=1.3038999080000846, svr__gamma=0.04467752817973904, svr__kernel=rbf;, score=-0.118 total time=   0.0s
# [CV 4/5] END svr__C=1.3038999080000846, svr__gamma=0.04467752817973904, svr__kernel=rbf;, score=-0.120 total time=   0.0s
# [CV 5/5] END svr__C=1.3038999080000846, svr__gamma=0.04467752817973904, svr__kernel=rbf;, score=-0.111 total time=   0.0s
# {'svr__C': 0.11292247147901223, 'svr__gamma': 0.7579479953347995, 'svr__kernel': 'rbf'}
# -0.09588691455731169

# %%
from scipy.stats import randint

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
# Number of features to consider at every split
max_features = randint(2, 12)
# Maximum number of levels in tree
max_depth = randint(1, 12)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
param_distribs_rf = {
    'randomforestregressor__bootstrap': bootstrap,
    'randomforestregressor__max_depth': max_depth,
    'randomforestregressor__max_features': randint(low=1, high=10),
    'randomforestregressor__min_samples_leaf': min_samples_leaf,
    'randomforestregressor__min_samples_split': min_samples_split,
    'randomforestregressor__n_estimators': n_estimators
}

selected_features = ['absoluteReturn', 'relativeToSPReturn','relativeToSectoralIndexReturn', 'closePrice',
'freeCashFlowPerShare', 'bookValuePerShare', 'marketCap', 'priceToSalesRatio', 'currentRatio']
X_train_by_sector_selected = {k: v[selected_features] for k, v in X_train_by_sector.items()}
X_test_by_sector_selected = {k: v[selected_features] for k, v in X_test_by_sector.items()}
long_tail_columns = ['closePrice', 'bookValuePerShare', 'marketCap', 'priceToSalesRatio', 'currentRatio']
noraml_columns = [k for k in X_train_by_sector_selected[list(X_train_by_sector_selected.keys())[0]].columns if k not in long_tail_columns]

prep_pipeline = ColumnTransformer([('lt', long_tail_scaler, long_tail_columns), ('normal', normal_scaler, noraml_columns)])

random_forest_pipeline = make_pipeline(prep_pipeline, RandomForestRegressor())

rnd_searc_rf = RandomizedSearchCV(
    random_forest_pipeline, param_distributions=param_distribs_rf, n_iter=14, cv=TimeSeriesSplit(n_splits=7, test_size=int(sector_data_size * 0.035), max_train_size=int(sector_data_size * 0.15)),
    scoring='neg_mean_absolute_error', random_state=42, verbose=3)

y_train_data = y_train_by_sector['Energy']
X_train_data = X_train_by_sector['Energy']
res = rnd_searc_rf.fit(X_train_data, y_train_data)
print(res.best_params_)
print(res.best_score_)
# max_feat low, bootstrap?, n_of_est big, max_depth?
# Out:
# Fitting 7 folds for each of 14 candidates, totalling 98 fits
# [CV 1/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.140 total time=   1.6s
# [CV 2/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.114 total time=   1.7s
# [CV 3/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.091 total time=   0.8s
# [CV 4/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.094 total time=   1.1s
# [CV 5/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.095 total time=   1.1s
# [CV 6/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.112 total time=   1.2s
# [CV 7/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.104 total time=   1.1s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.137 total time=   1.0s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.116 total time=   1.0s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.088 total time=   1.1s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.094 total time=   1.0s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.099 total time=   1.0s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.116 total time=   1.4s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.109 total time=   1.2s
# [CV 1/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=227;, score=-0.131 total time=   0.8s
# [CV 2/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=227;, score=-0.115 total time=   1.0s
# [CV 3/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=227;, score=-0.090 total time=   0.8s
# [CV 4/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=227;, score=-0.092 total time=   0.8s
# [CV 5/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=227;, score=-0.096 total time=   0.7s
# [CV 6/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=227;, score=-0.106 total time=   0.8s
# [CV 7/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=4, randomforestregressor__max_features=8, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=227;, score=-0.103 total time=   0.7s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.156 total time=   0.0s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.119 total time=   0.0s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.096 total time=   0.0s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.100 total time=   0.0s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.099 total time=   0.0s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.118 total time=   0.0s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.112 total time=   0.0s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.159 total time=   0.0s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.119 total time=   0.0s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.102 total time=   0.0s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.102 total time=   0.0s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.100 total time=   0.0s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.135 total time=   0.0s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=6, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=10;, score=-0.112 total time=   0.0s
# [CV 1/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=11, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=118;, score=-0.132 total time=   0.3s
# [CV 2/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=11, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=118;, score=-0.116 total time=   0.3s
# [CV 3/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=11, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=118;, score=-0.088 total time=   0.3s
# [CV 4/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=11, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=118;, score=-0.092 total time=   0.3s
# [CV 5/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=11, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=118;, score=-0.098 total time=   0.3s
# [CV 6/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=11, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=118;, score=-0.109 total time=   0.3s
# [CV 7/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=11, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=4, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=118;, score=-0.105 total time=   0.4s
# [CV 1/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.139 total time=   1.2s
# [CV 2/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.113 total time=   0.9s
# [CV 3/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.090 total time=   0.9s
# [CV 4/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.093 total time=   0.8s
# [CV 5/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.095 total time=   0.8s
# [CV 6/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.113 total time=   0.8s
# [CV 7/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=3, randomforestregressor__max_features=7, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=336;, score=-0.104 total time=   0.7s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=4, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=500;, score=-0.150 total time=   1.8s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=4, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=500;, score=-0.116 total time=   2.1s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=4, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=500;, score=-0.089 total time=   2.0s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=4, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=500;, score=-0.100 total time=   2.1s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=4, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=500;, score=-0.097 total time=   2.2s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=4, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=500;, score=-0.127 total time=   2.1s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=4, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=500;, score=-0.116 total time=   2.0s
# [CV 1/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=10, randomforestregressor__max_features=5, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=336;, score=-0.138 total time=   1.2s
# [CV 2/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=10, randomforestregressor__max_features=5, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=336;, score=-0.115 total time=   1.3s
# [CV 3/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=10, randomforestregressor__max_features=5, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=336;, score=-0.093 total time=   1.3s
# [CV 4/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=10, randomforestregressor__max_features=5, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=336;, score=-0.094 total time=   1.4s
# [CV 5/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=10, randomforestregressor__max_features=5, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=336;, score=-0.098 total time=   1.3s
# [CV 6/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=10, randomforestregressor__max_features=5, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=336;, score=-0.109 total time=   1.3s
# [CV 7/7] END randomforestregressor__bootstrap=True, randomforestregressor__max_depth=10, randomforestregressor__max_features=5, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=336;, score=-0.105 total time=   1.3s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=173;, score=-0.140 total time=   0.5s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=173;, score=-0.116 total time=   0.5s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=173;, score=-0.097 total time=   0.5s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=173;, score=-0.096 total time=   0.5s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=173;, score=-0.097 total time=   0.5s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=173;, score=-0.115 total time=   0.4s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=3, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=173;, score=-0.106 total time=   0.4s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=282;, score=-0.144 total time=   0.9s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=282;, score=-0.116 total time=   0.9s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=282;, score=-0.099 total time=   0.8s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=282;, score=-0.096 total time=   0.9s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=282;, score=-0.097 total time=   0.8s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=282;, score=-0.116 total time=   0.8s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=8, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=5, randomforestregressor__n_estimators=282;, score=-0.106 total time=   0.8s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.148 total time=   0.2s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.118 total time=   0.2s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.100 total time=   0.2s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.097 total time=   0.2s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.099 total time=   0.2s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.115 total time=   0.2s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=10, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.107 total time=   0.2s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=2, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.139 total time=   0.5s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=2, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.114 total time=   0.5s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=2, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.092 total time=   0.7s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=2, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.094 total time=   0.6s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=2, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.096 total time=   0.5s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=2, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.112 total time=   0.4s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=2, randomforestregressor__max_features=4, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=391;, score=-0.105 total time=   0.4s
# [CV 1/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=7, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.175 total time=   0.2s
# [CV 2/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=7, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.124 total time=   0.2s
# [CV 3/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=7, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.098 total time=   0.2s
# [CV 4/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=7, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.102 total time=   0.2s
# [CV 5/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=7, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.105 total time=   0.2s
# [CV 6/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=7, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.131 total time=   0.2s
# [CV 7/7] END randomforestregressor__bootstrap=False, randomforestregressor__max_depth=7, randomforestregressor__max_features=9, randomforestregressor__min_samples_leaf=2, randomforestregressor__min_samples_split=2, randomforestregressor__n_estimators=64;, score=-0.117 total time=   0.2s
# {'randomforestregressor__bootstrap': True, 'randomforestregressor__max_depth': 4, 'randomforestregressor__max_features': 8, 'randomforestregressor__min_samples_leaf': 4, 'randomforestregressor__min_samples_split': 5, 'randomforestregressor__n_estimators': 227}
# -0.10466610318195624

# %%
param_distribs_rf = {
    'lasso__alpha': uniform(0.01, 3)
}

lasso_pipeline = make_pipeline(prep_pipeline, Lasso())
rnd_searc_lasso = RandomizedSearchCV(
    lasso_pipeline, param_distributions=param_distribs_rf, n_iter=20, cv=4,
    scoring='neg_root_mean_squared_error', random_state=42, verbose=3)

y_train_data = y_train_by_sector['Materials']
X_train_data = X_train_by_sector['Materials']
res = rnd_searc_lasso.fit(X_train_data, y_train_data)
print(res.best_params_)
print(res.best_score_)
# Out:
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# [CV 1/4] END ..lasso__alpha=1.1336203565420875;, score=-0.199 total time=   0.2s
# [CV 2/4] END ..lasso__alpha=1.1336203565420875;, score=-0.224 total time=   0.1s
# [CV 3/4] END ..lasso__alpha=1.1336203565420875;, score=-0.204 total time=   0.1s
# [CV 4/4] END ..lasso__alpha=1.1336203565420875;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=2.8621429192297483;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=2.8621429192297483;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=2.8621429192297483;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=2.8621429192297483;, score=-0.175 total time=   0.0s
# [CV 1/4] END ...lasso__alpha=2.205981825434215;, score=-0.199 total time=   0.0s
# [CV 2/4] END ...lasso__alpha=2.205981825434215;, score=-0.224 total time=   0.0s
# [CV 3/4] END ...lasso__alpha=2.205981825434215;, score=-0.204 total time=   0.0s
# [CV 4/4] END ...lasso__alpha=2.205981825434215;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=1.8059754525911098;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=1.8059754525911098;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=1.8059754525911098;, score=-0.204 total time=   0.1s
# [CV 4/4] END ..lasso__alpha=1.8059754525911098;, score=-0.175 total time=   0.1s
# [CV 1/4] END .lasso__alpha=0.47805592132730956;, score=-0.199 total time=   0.1s
# [CV 2/4] END .lasso__alpha=0.47805592132730956;, score=-0.224 total time=   0.1s
# [CV 3/4] END .lasso__alpha=0.47805592132730956;, score=-0.204 total time=   0.1s
# [CV 4/4] END .lasso__alpha=0.47805592132730956;, score=-0.175 total time=   0.0s
# [CV 1/4] END .lasso__alpha=0.47798356100860795;, score=-0.199 total time=   0.2s
# [CV 2/4] END .lasso__alpha=0.47798356100860795;, score=-0.224 total time=   0.0s
# [CV 3/4] END .lasso__alpha=0.47798356100860795;, score=-0.204 total time=   0.0s
# [CV 4/4] END .lasso__alpha=0.47798356100860795;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=0.1842508365045984;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=0.1842508365045984;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=0.1842508365045984;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=0.1842508365045984;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=2.6085284373248054;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=2.6085284373248054;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=2.6085284373248054;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=2.6085284373248054;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=1.8133450352296265;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=1.8133450352296265;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=1.8133450352296265;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=1.8133450352296265;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=2.1342177333881365;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=2.1342177333881365;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=2.1342177333881365;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=2.1342177333881365;, score=-0.175 total time=   0.0s
# [CV 1/4] END .lasso__alpha=0.07175348288740734;, score=-0.199 total time=   0.0s
# [CV 2/4] END .lasso__alpha=0.07175348288740734;, score=-0.224 total time=   0.0s
# [CV 3/4] END .lasso__alpha=0.07175348288740734;, score=-0.204 total time=   0.0s
# [CV 4/4] END .lasso__alpha=0.07175348288740734;, score=-0.175 total time=   0.0s
# [CV 1/4] END ...lasso__alpha=2.919729556485983;, score=-0.199 total time=   0.0s
# [CV 2/4] END ...lasso__alpha=2.919729556485983;, score=-0.224 total time=   0.0s
# [CV 3/4] END ...lasso__alpha=2.919729556485983;, score=-0.204 total time=   0.0s
# [CV 4/4] END ...lasso__alpha=2.919729556485983;, score=-0.175 total time=   0.0s
# [CV 1/4] END ...lasso__alpha=2.507327922401265;, score=-0.199 total time=   0.0s
# [CV 2/4] END ...lasso__alpha=2.507327922401265;, score=-0.224 total time=   0.0s
# [CV 3/4] END ...lasso__alpha=2.507327922401265;, score=-0.204 total time=   0.0s
# [CV 4/4] END ...lasso__alpha=2.507327922401265;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=0.6470173320348285;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=0.6470173320348285;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=0.6470173320348285;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=0.6470173320348285;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=0.5554749016213019;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=0.5554749016213019;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=0.5554749016213019;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=0.5554749016213019;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=0.5602135295603015;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=0.5602135295603015;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=0.5602135295603015;, score=-0.204 total time=   0.1s
# [CV 4/4] END ..lasso__alpha=0.5602135295603015;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=0.9227267288786132;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=0.9227267288786132;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=0.9227267288786132;, score=-0.204 total time=   0.1s
# [CV 4/4] END ..lasso__alpha=0.9227267288786132;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=1.5842692948967134;, score=-0.199 total time=   0.0s
# [CV 2/4] END ..lasso__alpha=1.5842692948967134;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=1.5842692948967134;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=1.5842692948967134;, score=-0.175 total time=   0.1s
# [CV 1/4] END ..lasso__alpha=1.3058350559263474;, score=-0.199 total time=   0.1s
# [CV 2/4] END ..lasso__alpha=1.3058350559263474;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=1.3058350559263474;, score=-0.204 total time=   0.1s
# [CV 4/4] END ..lasso__alpha=1.3058350559263474;, score=-0.175 total time=   0.0s
# [CV 1/4] END ..lasso__alpha=0.8836874205941257;, score=-0.199 total time=   0.1s
# [CV 2/4] END ..lasso__alpha=0.8836874205941257;, score=-0.224 total time=   0.0s
# [CV 3/4] END ..lasso__alpha=0.8836874205941257;, score=-0.204 total time=   0.0s
# [CV 4/4] END ..lasso__alpha=0.8836874205941257;, score=-0.175 total time=   0.0s
# {'lasso__alpha': 1.1336203565420875}
# -0.2005243227734133

# %%
lasso_feat_selection = SelectFromModel(estimator=Lasso(alpha=1.13))
rf_feat_selection = SelectFromModel(estimator=RandomForestRegressor(max_features=4, n_estimators=800, bootstrap=True))

for sector, y_train_data in y_train_by_sector.items():
    X_train_data = X_train_by_sector[sector]
    print(lasso_feat_selection.fit(X=X_train_data, y=y_train_data).get_feature_names_out())
    print(rf_feat_selection.fit(X=X_train_data, y=y_train_data).get_feature_names_out())
# Out:
# []
# ['absoluteReturn' 'relativeToSPReturn' 'relativeToSectoralIndexReturn'
#  'closePrice' 'marketCap' 'currentRatio' 'netCurrentAssetValuePerShare']
# []
# ['absoluteReturn' 'relativeToSPReturn' 'relativeToSectoralIndexReturn'
#  'closePrice' 'marketCap']
# []
# ['absoluteReturn' 'relativeToSPReturn' 'closePrice'
#  'dilutedEarningsPerShare' 'freeCashFlowPerShare' 'bookValuePerShare'
#  'marketCap' 'priceToSalesRatio']

# %%
selected_features = ['closePrice',
'freeCashFlowPerShare', 'bookValuePerShare', 'marketCap', 'priceToSalesRatio', 'currentRatio']
X_train_by_sector_selected = {k: v[selected_features] for k, v in X_train_by_sector.items()}
X_test_by_sector_selected = {k: v[selected_features] for k, v in X_test_by_sector.items()}
long_tail_columns = ['closePrice', 'bookValuePerShare', 'marketCap', 'priceToSalesRatio', 'currentRatio']
noraml_columns = [k for k in X_train_by_sector_selected[list(X_train_by_sector_selected.keys())[0]].columns if k not in long_tail_columns]

prep_pipeline = ColumnTransformer([('lt', long_tail_scaler, long_tail_columns), ('normal', normal_scaler, noraml_columns)])


linear_regr_pipeline = make_pipeline(prep_pipeline, LinearRegression())
svr_pipeline = make_pipeline(prep_pipeline, SVR(C=1.2, gamma=1e-5))

random_forest_pipeline = make_pipeline(prep_pipeline, RandomForestRegressor(max_features=8, max_depth=4, n_estimators=300, bootstrap=True,random_state=42))

pipelines = [('Linear regr', linear_regr_pipeline), ('SVR', svr_pipeline)
    , ('Random forest', random_forest_pipeline)]

out_table = None
for sector, y_train_data in y_train_by_sector.items():
    print(sector)
    sector_data_size = len(data_by_sector.get_group(sector))
    X_train_data = X_train_by_sector_selected[sector]
    X_test_data = X_test_by_sector_selected[sector]
    y_test_data = y_test_by_sector[sector]
    methods_table_for_sector = pd.DataFrame(columns=['Алгоритм', 'Статистика','Показатель статистики', 'Значение'])
    for name, pipeline in pipelines:
        print(name)
        cv_num = 10
        # rmses = -cross_val_score(pipeline, X_train_data, y_train_data,
        #                           scoring="r2", cv=TimeSeriesSplit(n_splits=5, test_size=int(X_train_data.index.size * 0.05), max_train_size=int(X_train_data.index.size / 6)))
        # print(pd.Series(rmses).describe())
        #
        # maes = -cross_val_score(pipeline, X_train_data, y_train_data,
        #                           scoring="neg_mean_absolute_error", cv=TimeSeriesSplit(n_splits=5, test_size=int(X_train_data.index.size * 0.05), max_train_size=int(X_train_data.index.size / 6)))
        # print(pd.Series(maes).describe())
        #
        #  mses = -cross_val_score(pipeline, X_train_data, y_train_data,
        #                           scoring="neg_root_mean_squared_error", cv=TimeSeriesSplit(n_splits=5, test_size=int(X_train_data.index.size * 0.05), max_train_size=int(X_train_data.index.size / 6)))
        # print(pd.Series(mses).describe())

        for scoring in scorings:
            scrs = -cross_val_score(pipeline, X_train_data, y_train_data,
                                      scoring=scoring, cv=5)
            print(pd.Series(scrs).describe())
            methods_table_for_sector = pd.concat([methods_table_for_sector, get_cross_val_row(scrs, scoring, name)])

        est = pipeline.fit(X_train_data, y_train_data)

        print('train: ')
        eval(est, X_train_data, y_train_data)
        print('test: ')
        eval(est, X_test_data, y_test_data)

    out = pd.Series(methods_table_for_sector['Значение'].array, index=pd.MultiIndex.from_frame(methods_table_for_sector.drop('Значение', axis=1))).to_frame(sector).transpose()
    if out_table is None:
        out_table = out
    else:
        out_table = pd.concat([out_table, out])
print(out_table)
out_table.to_excel('out_table_tuned_selected_cs.xlsx')
# Out:
# Energy
# Linear regr
# count    5.000000
# mean    -0.002033
# std      0.045217
# min     -0.045329
# 25%     -0.013856
# 50%     -0.012972
# 75%     -0.012947
# max      0.074941
# dtype: float64
# count    5.000000
# mean     0.104187
# std      0.012603
# min      0.088687
# 25%      0.099260
# 50%      0.100822
# 75%      0.109905
# max      0.122263
# dtype: float64
# count    5.000000
# mean     0.145369
# std      0.020332
# min      0.121072
# 25%      0.134037
# 50%      0.140139
# 75%      0.159769
# max      0.171829
# dtype: float64
# train:
# Model Performance
#   Статистика             Значение
# 0        MSE  0.14522948460322932
# 1        MAE  0.10328220618572871
# 2         R2  0.02511871497636753
# test:
# Model Performance
#   Статистика              Значение
# 0        MSE   0.31179340142010314
# 1        MAE   0.18191767794534552
# 2         R2  0.037008013550086316
# SVR
# count    5.000000
# mean    -0.001820
# std      0.007309
# min     -0.008066
# 25%     -0.004854
# 50%     -0.004594
# 75%     -0.002318
# max      0.010730
# dtype: float64
# count    5.000000
# mean     0.103819
# std      0.012715
# min      0.089658
# 25%      0.097268
# 50%      0.100016
# 75%      0.109437
# max      0.122719
# dtype: float64
# count    5.000000
# mean     0.145459
# std      0.020613
# min      0.123628
# 25%      0.129972
# 50%      0.140778
# 75%      0.160163
# max      0.172754
# dtype: float64
# train:
# Model Performance
#   Статистика              Значение
# 0        MSE   0.14613756080556842
# 1        MAE    0.1035332715322623
# 2         R2  0.012889322993450025
# test:
# Model Performance
#   Статистика               Значение
# 0        MSE    0.31853987119369037
# 1        MAE     0.1838129967871259
# 2         R2  -0.005116572354711302
# Random forest
# count    5.000000
# mean     0.008533
# std      0.081595
# min     -0.045647
# 25%     -0.039107
# 50%     -0.020686
# 75%     -0.003364
# max      0.151469
# dtype: float64
# count    5.000000
# mean     0.104555
# std      0.012874
# min      0.088671
# 25%      0.100255
# 50%      0.101491
# 75%      0.108681
# max      0.123679
# dtype: float64
# count    5.000000
# mean     0.145866
# std      0.018954
# min      0.121466
# 25%      0.138726
# 50%      0.140883
# 75%      0.157100
# max      0.171156
# dtype: float64
# train:
# Model Performance
#   Статистика             Значение
# 0        MSE  0.13876844440981262
# 1        MAE  0.10092492835273262
# 2         R2  0.10993119384847683
# test:
# Model Performance
#   Статистика             Значение
# 0        MSE   0.2907624397289176
# 1        MAE  0.17702987888775823
# 2         R2  0.16253735967179417
# Industrials
# Linear regr
# count    5.000000
# mean    -0.015362
# std      0.019998
# min     -0.040902
# 25%     -0.022429
# 50%     -0.016012
# 75%     -0.011847
# max      0.014382
# dtype: float64
# count    5.000000
# mean     0.086049
# std      0.014998
# min      0.074828
# 25%      0.077674
# 50%      0.079637
# 75%      0.086318
# max      0.111788
# dtype: float64
# count    5.000000
# mean     0.124934
# std      0.028966
# min      0.098531
# 25%      0.104723
# 50%      0.118140
# 75%      0.131913
# max      0.171362
# dtype: float64
# train:
# Model Performance
#   Статистика             Значение
# 0        MSE   0.1268661667721685
# 1        MAE  0.08553394443850192
# 2         R2   0.0331474478343895
# test:
# Model Performance
#   Статистика                Значение
# 0        MSE     0.11693041717027941
# 1        MAE     0.08754432665748219
# 2         R2  -0.0027120700727707447
# SVR
# count    5.000000
# mean    -0.009205
# std      0.002556
# min     -0.012584
# 25%     -0.011148
# 50%     -0.008161
# 75%     -0.007657
# max     -0.006476
# dtype: float64
# count    5.000000
# mean     0.085384
# std      0.015288
# min      0.072820
# 25%      0.077613
# 50%      0.079292
# 75%      0.085745
# max      0.111450
# dtype: float64
# count    5.000000
# mean     0.125498
# std      0.029904
# min      0.097283
# 25%      0.104684
# 50%      0.118610
# 75%      0.134260
# max      0.172652
# dtype: float64
# train:
# Model Performance
#   Статистика             Значение
# 0        MSE  0.12800296231862726
# 1        MAE  0.08525012368663441
# 2         R2  0.01574268096407072
# test:
# Model Performance
#   Статистика             Значение
# 0        MSE  0.11630772221436099
# 1        MAE  0.08702401998167308
# 2         R2  0.00793907158093432
# Random forest
# count    5.000000
# mean     0.012026
# std      0.075304
# min     -0.040057
# 25%     -0.021754
# 50%     -0.014959
# 75%     -0.008145
# max      0.145044
# dtype: float64
# count    5.000000
# mean     0.086642
# std      0.015128
# min      0.072822
# 25%      0.077808
# 50%      0.082056
# 75%      0.088980
# max      0.111540
# dtype: float64
# count    5.000000
# mean     0.126279
# std      0.027496
# min      0.097430
# 25%      0.112730
# 50%      0.118203
# 75%      0.133223
# max      0.169810
# dtype: float64
# train:
# Model Performance
#   Статистика             Значение
# 0        MSE  0.11754953681156338
# 1        MAE  0.08351991336153096
# 2         R2  0.16993814536459206
# test:
# Model Performance
#   Статистика              Значение
# 0        MSE   0.11650422157978274
# 1        MAE   0.08722366545258897
# 2         R2  0.004584109209251008
# Materials
# Linear regr
# count    5.000000
# mean    -0.003248
# std      0.030587
# min     -0.020545
# 25%     -0.017387
# 50%     -0.015284
# 75%     -0.014325
# max      0.051301
# dtype: float64
# count    5.000000
# mean     0.136152
# std      0.020039
# min      0.116529
# 25%      0.121952
# 50%      0.131408
# 75%      0.144183
# max      0.166689
# dtype: float64
# count    5.000000
# mean     0.196572
# std      0.031314
# min      0.158575
# 25%      0.178350
# 50%      0.194831
# 75%      0.210328
# max      0.240778
# dtype: float64
# train:
# Model Performance
#   Статистика              Значение
# 0        MSE    0.1972797179857517
# 1        MAE   0.13514339376853968
# 2         R2  0.033620539482684064
# test:
# Model Performance
#   Статистика              Значение
# 0        MSE    0.2227860193244857
# 1        MAE    0.1540554443109686
# 2         R2  0.026608196245606952
# SVR
# count    5.000000
# mean     0.006278
# std      0.022986
# min     -0.015359
# 25%     -0.009325
# 50%     -0.005555
# 75%      0.025430
# max      0.036196
# dtype: float64
# count    5.000000
# mean     0.134278
# std      0.021938
# min      0.109796
# 25%      0.120697
# 50%      0.132337
# 75%      0.141288
# max      0.167270
# dtype: float64
# count    5.000000
# mean     0.197935
# std      0.034364
# min      0.154228
# 25%      0.178802
# 50%      0.200395
# 75%      0.210544
# max      0.245705
# dtype: float64
# train:
# Model Performance
#   Статистика              Значение
# 0        MSE   0.19958438958476993
# 1        MAE    0.1338028001573765
# 2         R2  0.010909673892826044
# test:
# Model Performance
#   Статистика              Значение
# 0        MSE   0.22566951573716665
# 1        MAE    0.1522819940956506
# 2         R2  0.001248116100044716
# Random forest
# count    5.000000
# mean    -0.024209
# std      0.026450
# min     -0.061959
# 25%     -0.040615
# 50%     -0.013620
# 75%     -0.007075
# max      0.002222
# dtype: float64
# count    5.000000
# mean     0.135063
# std      0.020642
# min      0.112452
# 25%      0.122745
# 50%      0.131454
# 75%      0.142379
# max      0.166286
# dtype: float64
# count    5.000000
# mean     0.194448
# std      0.030221
# min      0.154829
# 25%      0.178414
# 50%      0.196166
# 75%      0.207827
# max      0.235002
# dtype: float64
# train:
# Model Performance
#   Статистика             Значение
# 0        MSE  0.18579891633996692
# 1        MAE   0.1313076750303205
# 2         R2   0.1428256488652938
# test:
# Model Performance
#   Статистика             Значение
# 0        MSE  0.22057355498064019
# 1        MAE   0.1521964946262408
# 2         R2  0.04584549941888316
# Алгоритм              Linear regr                                          \
# Статистика                     R2                 MAE                RMSE
# Показатель статистики        mean       std      mean       std      mean
# Energy                  -0.002033  0.045217  0.104187  0.012603  0.145369
# Industrials             -0.015362  0.019998  0.086049  0.014998  0.124934
# Materials               -0.003248  0.030587  0.136152  0.020039  0.196572
#
# Алгоритм                              SVR                                \
# Статистика                             R2                 MAE
# Показатель статистики       std      mean       std      mean       std
# Energy                 0.020332 -0.001820  0.007309  0.103819  0.012715
# Industrials            0.028966 -0.009205  0.002556  0.085384  0.015288
# Materials              0.031314  0.006278  0.022986  0.134278  0.021938
#
# Алгоритм                                  Random forest                      \
# Статистика                 RMSE                      R2                 MAE
# Показатель статистики      mean       std          mean       std      mean
# Energy                 0.145459  0.020613      0.008533  0.081595  0.104555
# Industrials            0.125498  0.029904      0.012026  0.075304  0.086642
# Materials              0.197935  0.034364     -0.024209  0.026450  0.135063
#
# Алгоритм
# Статистика                           RMSE
# Показатель статистики       std      mean       std
# Energy                 0.012874  0.145866  0.018954
# Industrials            0.015128  0.126279  0.027496
# Materials              0.020642  0.194448  0.030221

# %%
selected_features = ['absoluteReturn', 'relativeToSPReturn', 'relativeToSectoralIndexReturn', 'closePrice',
                     'freeCashFlowPerShare', 'bookValuePerShare', 'marketCap', 'priceToSalesRatio', 'currentRatio']
X_train_by_sector_selected = {k: v[selected_features] for k, v in X_train_by_sector.items()}
X_test_by_sector_selected = {k: v[selected_features] for k, v in X_test_by_sector.items()}
long_tail_columns = ['closePrice', 'bookValuePerShare', 'marketCap', 'priceToSalesRatio', 'currentRatio']
noraml_columns = [k for k in X_train_by_sector_selected[list(X_train_by_sector_selected.keys())[0]].columns if
                  k not in long_tail_columns]

prep_pipeline = ColumnTransformer(
    [('lt', long_tail_scaler, long_tail_columns), ('normal', normal_scaler, noraml_columns)])

linear_regr_pipeline = make_pipeline(prep_pipeline, LinearRegression())
svr_pipeline = make_pipeline(prep_pipeline, SVR(C=1.2, gamma=1e-5))

random_forest_pipeline = make_pipeline(prep_pipeline,
                                       RandomForestRegressor(max_features=8, max_depth=4, n_estimators=300,
                                                             bootstrap=True, random_state=42))

pipelines = [('Linear regr', linear_regr_pipeline), ('SVR', svr_pipeline)
    , ('Random forest', random_forest_pipeline)]

out_table = None
for sector, y_train_data in y_train_by_sector.items():
    print(sector)
    X_train_data = X_train_by_sector_selected[sector]
    X_test_data = X_test_by_sector_selected[sector]
    y_test_data = y_test_by_sector[sector]
    methods_table_for_sector = pd.DataFrame(columns=['Алгоритм', 'Сет', 'Статистика', 'Значение'])
    for name, pipeline in pipelines:
        print(name)

        est = pipeline.fit(X_train_data, y_train_data)

        print('train: ')
        stats_train = eval(est, X_train_data, y_train_data)
        stats_train.insert(0, 'Сет', 'train')
        print('test: ')
        stats_test = eval(est, X_test_data, y_test_data)
        stats_test.insert(0, 'Сет', 'test')

        stats_for_algo = pd.concat([stats_train, stats_test])
        stats_for_algo.insert(0, 'Алгоритм', name)
        methods_table_for_sector = pd.concat([methods_table_for_sector, stats_for_algo])


    out = pd.Series(methods_table_for_sector['Значение'].array,
                    index=pd.MultiIndex.from_frame(methods_table_for_sector.drop('Значение', axis=1))).to_frame(
        sector).transpose()
    if out_table is None:
        out_table = out
    else:
        out_table = pd.concat([out_table, out])
print(out_table)
out_table.to_excel('out_table_tuned_selected_train_test.xlsx')
# Out:
# Energy
# Linear regr
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.144696
# 1        MAE  0.103085
# 2         R2  0.032268
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.315610
# 1        MAE  0.185252
# 2         R2  0.013285
# SVR
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.145924
# 1        MAE  0.103411
# 2         R2  0.015767
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.318998
# 1        MAE  0.183976
# 2         R2 -0.008010
# Random forest
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.137937
# 1        MAE  0.100445
# 2         R2  0.120564
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.295719
# 1        MAE  0.178578
# 2         R2  0.133743
# Industrials
# Linear regr
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.126771
# 1        MAE  0.085646
# 2         R2  0.034593
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.117086
# 1        MAE  0.087518
# 2         R2 -0.005379
# SVR
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.128034
# 1        MAE  0.085239
# 2         R2  0.015259
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.116251
# 1        MAE  0.086994
# 2         R2  0.008913
# Random forest
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.115773
# 1        MAE  0.083192
# 2         R2  0.194843
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.116743
# 1        MAE  0.087369
# 2         R2  0.000498
# Materials
# Linear regr
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.196808
# 1        MAE  0.135163
# 2         R2  0.038232
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.221899
# 1        MAE  0.153370
# 2         R2  0.034341
# SVR
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.199484
# 1        MAE  0.133809
# 2         R2  0.011906
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.225521
# 1        MAE  0.152325
# 2         R2  0.002565
# Random forest
# train:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.185358
# 1        MAE  0.131125
# 2         R2  0.146889
# test:
# Model Performance
#   Статистика  Значение
# 0       RMSE  0.219747
# 1        MAE  0.151762
# 2         R2  0.052986
# Алгоритм    Linear regr                                                    \
# Сет               train                          test
# Статистика         RMSE       MAE        R2      RMSE       MAE        R2
# Energy         0.144696  0.103085  0.032268  0.315610  0.185252  0.013285
# Industrials    0.126771  0.085646  0.034593  0.117086  0.087518 -0.005379
# Materials      0.196808  0.135163  0.038232  0.221899  0.153370  0.034341
#
# Алгоритм          SVR                                                    \
# Сет             train                          test
# Статистика       RMSE       MAE        R2      RMSE       MAE        R2
# Energy       0.145924  0.103411  0.015767  0.318998  0.183976 -0.008010
# Industrials  0.128034  0.085239  0.015259  0.116251  0.086994  0.008913
# Materials    0.199484  0.133809  0.011906  0.225521  0.152325  0.002565
#
# Алгоритм    Random forest
# Сет                 train                          test
# Статистика           RMSE       MAE        R2      RMSE       MAE        R2
# Energy           0.137937  0.100445  0.120564  0.295719  0.178578  0.133743
# Industrials      0.115773  0.083192  0.194843  0.116743  0.087369  0.000498
# Materials        0.185358  0.131125  0.146889  0.219747  0.151762  0.052986
